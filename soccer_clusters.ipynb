# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_html('https://fbref.com/en/comps/9/possession/Premier-League-Stats', 
                  attrs={'id' :"stats_squads_possession_for"}, header=None, skiprows=[0])[0]

# %%
df.head()
# Out:
#          Squad # Pl  Poss   90s Touches Def Pen Def 3rd Mid 3rd Att 3rd  \
#        Arsenal   23  54.4  16.0    9751     830    2642    4171    3016
# 0  Aston Villa   23  50.5  16.0    9146    1024    3037    3933    2268
# 1  Bournemouth   25  45.3  16.0    8771     937    2655    3678    2555
# 2    Brentford   23  46.9  16.0    9275    1504    3793    3418    2143
# 3     Brighton   28  53.4  16.0   10166    1171    3303    4466    2512
# 4      Chelsea   24  56.5  16.0   10549     997    3284    4683    2666
#
#   Att Pen  ... Carries TotDist PrgDist PrgC  1/3  CPA  Mis  Dis   Rec PrgR
#       547  ...    5562   29362   15609  333  198  126  191  182  6717  730
# 0     423  ...    5299   29121   15518  294  194   93  212  168  6168  563
# 1     439  ...    4765   27363   14312  305  204  107  237  151  5087  651
# 2     351  ...    5033   26554   13062  226  151   70  228  135  5755  568
# 3     423  ...    6024   33529   18548  343  243  109  239  148  6871  678
# ...

# %%
df.describe()
# Out:
#             # Pl       Poss        90s       Touches      Def Pen  \
#               23       54.4       16.0          9751          830
# count  19.000000  19.000000  19.000000     19.000000    19.000000
# mean   24.578947  49.747368  15.894737   9542.578947  1103.736842
# std     2.340840   6.224179   0.315302   1093.699193   168.318759
# min    21.000000  39.900000  15.000000   7487.000000   836.000000
# 25%    23.000000  45.700000  16.000000   8846.000000   998.500000
# 50%    24.000000  50.100000  16.000000   9278.000000  1074.000000
# 75%    25.000000  53.650000  16.000000  10254.500000  1178.000000
# max    31.000000  62.700000  16.000000  12139.000000  1504.000000
#
#            Def 3rd      Mid 3rd      Att 3rd     Att Pen          Live  ...  \
#               2642         4171         3016         547          9749  ...
# count    19.000000    19.000000    19.000000   19.000000     19.000000  ...
# mean   3210.894737  4009.894737  2416.631579  397.421053   9540.842105  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Squad, Arsenal)  19 non-null     object
#  1   (# Pl, 23)        19 non-null     int64
#  2   (Poss, 54.4)      19 non-null     float64
#  3   (90s, 16.0)       19 non-null     float64
#  4   (Touches, 9751)   19 non-null     int64
#  5   (Def Pen, 830)    19 non-null     int64
#  6   (Def 3rd, 2642)   19 non-null     int64
#  7   (Mid 3rd, 4171)   19 non-null     int64
#  8   (Att 3rd, 3016)   19 non-null     int64
#  9   (Att Pen, 547)    19 non-null     int64
#  10  (Live, 9749)      19 non-null     int64
#  11  (Att, 311)        19 non-null     int64
#  12  (Succ, 136)       19 non-null     int64
#  13  (Succ%, 43.7)     19 non-null     float64
#  14  (Tkld, 133)       19 non-null     int64
#  15  (Tkld%, 42.8)     19 non-null     float64
# ...

# %%
df.isnull().sum()
# Out:
# Squad    Arsenal    0
# # Pl     23         0
# Poss     54.4       0
# 90s      16.0       0
# Touches  9751       0
# Def Pen  830        0
# Def 3rd  2642       0
# Mid 3rd  4171       0
# Att 3rd  3016       0
# Att Pen  547        0
# Live     9749       0
# Att      311        0
# Succ     136        0
# Succ%    43.7       0
# Tkld     133        0
# Tkld%    42.8       0
# Carries  5562       0
# TotDist  29362      0
# PrgDist  15609      0
# PrgC     333        0
# 1/3      198        0
# CPA      126        0
# Mis      191        0
# Dis      182        0
# Rec      6717       0
# PrgR     730        0
# dtype: int64

# %%
df.iloc[:,:].hist(bins=15, figsize=(15, 10), layout=(6, 5), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Features', fontsize=14)
plt.show()

# %%
df.drop("90s", axis=1, inplace=True)
df.drop("Squad", axis=1, inplace=True)
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_16868\1475065611.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop("90s", axis=1, inplace=True)
# C:\Users\jacob\AppData\Local\Temp\ipykernel_16868\1475065611.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop("Squad", axis=1, inplace=True)

# %%
corr_matrix = df.iloc[:,1:].corr()
sns.heatmap(corr_matrix)
# Out:
# <Axes: xlabel='None-None', ylabel='None-None'>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
pca = PCA(n_components=3)
pca_df = pca.fit_transform(df_scaled)

# %%
plt.scatter(pca_df[:, 0], pca_df[:, 1], pca_df[:, 2])
plt.title("PCA Visualization of Data")
plt.show()
# Out:
# c:\Users\jacob\anaconda3\envs\tf\lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
from sklearn.cluster import KMeans

# %%
data = list(zip)

# %%
# definitions
# Question: Comparing the workload of top teams to

# %%
from statsbombpy import sb
import pandas as pd
from mplsoccer import VerticalPitch,Pitch

events_df = sb.competition_events(
country="Germany",
division="1. Bundesliga",
season="2023/2024",
gender="male")

frames_df = sb.competition_frames(
country="Germany",
division="1. Bundesliga",
season="2023/2024",
gender="male")

frames_df.rename(columns={'event_uuid': 'id'}, inplace = True)
merged_df=pd.merge(frames_df, events_df,
how="left", on=["match_id","id"])

# %%
print(frames_df.shape)
print(events_df.shape)
# Out:
# (1953182, 7)
# (137765, 111)

# %%
frames_df.head()
# Out:
#    actor                                    id  keeper  \
# 0  False  ff56e821-21e9-4cef-ba2a-7eb5eb3769c6   False
# 1  False  ff56e821-21e9-4cef-ba2a-7eb5eb3769c6   False
# 2  False  ff56e821-21e9-4cef-ba2a-7eb5eb3769c6   False
# 3  False  ff56e821-21e9-4cef-ba2a-7eb5eb3769c6   False
# 4  False  ff56e821-21e9-4cef-ba2a-7eb5eb3769c6   False
#
#                                    location match_id  teammate  \
# 0  [33.623681824113135, 40.159018633164074]  3895302      True
# 1    [36.74041423873898, 53.63999223538578]  3895302      True
# 2   [41.68140190196648, 24.747150774999632]  3895302      True
# 3    [45.75852507051164, 34.30730339844553]  3895302      True
# 4    [49.77081997053183, 49.75472239512554]  3895302      True
#
#                                         visible_area
# 0  [16.638549335883955, 80.0, 42.634221931834276,...
# 1  [16.638549335883955, 80.0, 42.634221931834276,...
# 2  [16.638549335883955, 80.0, 42.634221931834276,...
# ...

# %%
frames_df.iloc[0, 3]
# Out:
# [33.623681824113135, 40.159018633164074]

# %%
events_df.head()
# Out:
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                            NaN              NaN             NaN
# 1                            NaN              NaN             NaN
# 2                            NaN              NaN             NaN
# 3                            NaN              NaN             NaN
# 4                            NaN              NaN             NaN
#
#   block_save_block carry_end_location clearance_aerial_won  ...  \
# 0              NaN                NaN                  NaN  ...
# ...

# %%
events_df.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'block_save_block',
#        'carry_end_location', 'clearance_aerial_won',
#        ...
#        'substitution_outcome', 'substitution_outcome_id',
#        'substitution_replacement', 'substitution_replacement_id', 'tactics',
#        'team', 'team_id', 'timestamp', 'type', 'under_pressure'],
#       dtype='object', length=111)

# %%
events_df.iloc[:,:].hist(bins=15, figsize=(15, 10), layout=(6, 5), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of Features', fontsize=14)
plt.show()
